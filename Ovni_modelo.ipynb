# %% [markdown]
# Regresion (Duracion del avistamiento)

# %%
from pycaret.regression import *

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\34650\Desktop\proyecto 3\Temario\Ovnis\UFO_final_csv.csv')

df.head()
# Out:
#              Date_time  Year  Month  Hour  Season Country_Code  \
# 0  1949-10-10 20:30:00  1949     10    20  Autumn          USA
# 1  1949-10-10 21:00:00  1949     10    21  Autumn          USA
# 2  1955-10-10 17:00:00  1955     10    17  Autumn          GBR
# 3  1956-10-10 21:00:00  1956     10    21  Autumn          USA
# 4  1960-10-10 20:00:00  1960     10    20  Autumn          USA
#
#           Country   Region                   Locale   latitude   longitude  \
# 0   United States    Texas               San Marcos  29.883056  -97.941111
# 1   United States    Texas  Lackland Air Force Base  29.384210  -98.581082
# 2  United Kingdom  England                   Blacon  53.200000   -2.916667
# 3   United States    Texas                     Edna  28.978333  -96.645833
# 4   United States   Hawaii                 Kane'ohe  21.418056 -157.803611
#
#   UFO_shape  duration_seconds Encounter_Duration  \
# 0  Cylinder            2700.0         45 minutes
# ...

# %%
df_pred = df.copy()
df_pred_new = df_pred[['Month', 'Hour', 'Country','UFO_shape','duration_seconds']]

# %%
df_pred_new.dtypes
# Out:
# Month                 int64
# Hour                  int64
# Country              object
# UFO_shape            object
# duration_seconds    float64
# dtype: object

# %%
df_pred_new.head()
# Out:
#    Month  Hour         Country UFO_shape  duration_seconds
# 0     10    20   United States  Cylinder            2700.0
# 1     10    21   United States     Light            7200.0
# 2     10    17  United Kingdom    Circle              20.0
# 3     10    21   United States    Circle              20.0
# 4     10    20   United States     Light             900.0

# %%
setup = setup(df_pred_new, target = 'duration_seconds')
# Out:
# <style type="text/css">
# #T_669ea_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_669ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_669ea_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_669ea_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_669ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_669ea_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_669ea_row0_col1" class="data row0 col1" >7772</td>
#     </tr>
#     <tr>
#       <th id="T_669ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_669ea_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_669ea_row1_col1" class="data row1 col1" >duration_seconds</td>
#     </tr>
#     <tr>
#       <th id="T_669ea_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_86722 th {
#   text-align: left;
# }
# ...

# %%
Huber_Regressor= create_model("huber")
# Out:
# <style type="text/css">
# #T_c4bcb_row10_col0, #T_c4bcb_row10_col1, #T_c4bcb_row10_col2, #T_c4bcb_row10_col3, #T_c4bcb_row10_col4, #T_c4bcb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c4bcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4bcb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c4bcb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c4bcb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c4bcb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c4bcb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c4bcb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_huber = tune_model(Huber_Regressor)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
evaluate_model(tuned_huber)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
final_huber_best = finalize_model(Huber_Regressor)

# %%
save_model(Huber_Regressor, "modelo_tiempo")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Month', 'Hour'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Country', 'UFO_shape'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['Country', 'UFO_shape'],
#                                      transformer=TargetEncoder(cols=['Country',
#                                                                      'UFO_shape'],
#                                                                handle_missing='return_nan'))),
#                  ('trained_model', HuberRegressor())]),
#  'modelo_tiempo.pkl')
